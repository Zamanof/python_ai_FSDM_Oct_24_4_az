# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5
# ###### Header 6

# %% [markdown]
# **Bold Text**
#
# *Italic*
#
# ***Bold Italic***
#
# ~~strikethrough text~~
#
# `code in row`
#
# `print("Hello")`

# %% [markdown]
# - Python
# - Pandas
# - Keras
# - Jupyter

# %% [markdown]
# * Python
# * Pandas
# * Keras
# * Jupyter

# %% [markdown]
# 1. Python
# 2. Pandas
# 3. Keras
# 4. Jupyter
# 5. NumPy

# %% [markdown]
# 1. Python
#     1. Variable
#     2. Datatypes
# 2. Pandas
#     - Some
#         - other
#     - Foo
# 3. Keras
# 4. Jupyter
# 5. NumPy

# %% [markdown]
# - [x] Python
# - [x] C++
# - [ ] C#
# - [ ] JavaScript

# %% [markdown]
# > Süni intellekt - İnformatikanın bir sahəsi
#
# > First Level
# >> Second Level
#
# ---
#
# ***

# %% [markdown]
# [Google](https://www.google.com/)

# %% [markdown]
# ![Jupyter Logo](https://jupyter.org/governance/build/config-item-351dae2c-91365342e3b7d90ad5fda2b4a086f880.png)

# %% [markdown]
# ```python
# a = 5
# b = 6
# c = a + b
# print(c)
# ```
#
# ```javascript
# document.getElementById("demo").innerHTML = "John" + " "  + "Doe";
# ```
#
# ```csharp
# Console.WriteLine("Hello")
# ```
#
# ```sql
# SELECT * FROM Books
# ```

# %% [markdown]
# | FirstName | LastName | Age |
# |-----------|----------|-----|
# | Nadir     | Zamanov  | 46  |
# | Ali       | Aliyev   | 35  |
#
#
# | FirstName |  LastName  |  Age |
# |:----------|:----------:|-----:|
# | Nadir     |  Zamanov   |   46 |
# | Ali       |   Aliyev   |   35 |

# %% [markdown]
# * LaTex
#
# $ E = mc^2 $
#
# $$
# E = mc^2
# $$
#
# $$
# \sigma = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (x_i - \mu)^2}
# $$
#
#
# $$
# \lim_{x \to \infty} f(x)
# $$
#
#
#
# $$
# \begin{matrix}
# 1 & 2 \\
# 3 & 4
# \end{matrix}
# $$

# %% [markdown]
# <h1 style="color:red;">Hello</h1>
# <img src="https://jupyter.org/governance/build/config-item-351dae2c-91365342e3b7d90ad5fda2b4a086f880.png" width=300px>

# %% [markdown]
# \* \#
